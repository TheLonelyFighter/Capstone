# %%
import numpy as np
import pandas as pd
from scipy import signal
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.integrate import simps
from scipy.fft import fftshift

# %%
link = 'C:\\Users\\Owner\\Downloads\\test3_car_park_skanssi.wav'
samplerate, data = wavfile.read(link)

# %%
samplerate

ts = np.arange(data.size)/samplerate

ts
# Out:
# array([0.00000000e+00, 2.26757370e-05, 4.53514739e-05, ...,
#        1.11455714e+02, 1.11455737e+02, 1.11455760e+02])

# %%
# %matplotlib notebook
plt.figure()
plt.plot(ts,data)
plt.title("Dry asphalt")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
testdata = data[33*samplerate:40*samplerate]

# %%
plt.figure()
plt.plot(testdata)
plt.title("10s of dry asphalt")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def bpf(arr, fs, lf, hf, order):
    wbut = [lf, hf]
    bbut, abut = signal.butter(order, wbut, btype ='bandpass', fs = fs)

    return signal.filtfilt(bbut, abut, arr)

def hpf(arr, fs, lf, order):
    wbut = lf
    bbut, abut = signal.butter(order, wbut, btype ='highpass', fs =fs)

    return signal.filtfilt(bbut, abut, arr)

# %%
pip install sounddevice --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sounddevice as sd
sd.play(data, samplerate)

# %%
data_f = bpf(data, samplerate, 0.2, 20, 2)

# %%
sd.play(data_f, samplerate)

# %%
link = 'C:\\Users\\Owner\\Downloads\\test4_skanssi.wav'
samplerate, data2 = wavfile.read(link)

# %%
# %matplotlib notebook
plt.figure()
plt.plot(data2)
plt.title("Wet asphalt")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f, Pxx_den = signal.welch(data2, samplerate, nperseg=len(data2))

plt.figure()
plt.plot(f, Pxx_den)
plt.title("frequency domain of wet asphalt")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f, Pxx_den = signal.welch(data, samplerate, nperseg=len(data))

plt.figure()
plt.plot(f, Pxx_den)
plt.title("frequency domain of dry asphalt")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f, Pxx_den = signal.welch(data, samplerate, nperseg=len(data))
f2, Pxx_den2 = signal.welch(data2, samplerate, nperseg=len(data2))
plt.figure()
plt.plot(f2, Pxx_den2)
plt.plot(f, Pxx_den)

plt.title("Dry concrete frequency domain vs wet asphalt")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f, t, Sxx = signal.spectrogram(data2, samplerate)

plt.figure()
plt.pcolormesh(t, f, Sxx, shading='gouraud')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_f = bpf(data2, samplerate,1,60, 2)

# %%
sd.play(data_f, samplerate)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5ede1b7d400f> in <module>
# ----> 1 sd.play(data_f, samplerate)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sounddevice.py in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     172         ctx.callback_exit()
#     173
# --> 174     ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     175                      ctx.output_dtype, callback, blocking,
#     176                      prime_output_buffers_using_stream_callback=False,
#
# ~\AppData\Roaming\Python\Python38\site-packages\sounddevice.py in start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2574                      blocking, **kwargs):
#    2575         stop()  # Stop previous playback/recording
# -> 2576         self.stream = StreamClass(samplerate=samplerate,
# ...

# %%
plt.figure()
plt.plot(data_f)
plt.title("Wet asphalt filtered 1-60 Hz")
plt.show()

# %%
plt.figure()
plt.plot(data_f)
plt.title("Wet asphalt filtered 1-60 Hz")
plt.show()

# %%
plt.figure()
plt.plot(np.abs(np.fft.fft(data)))
plt.show()

# %%
plt.figure()
plt.plot(np.abs(np.fft.fft(data2)))
plt.title("FFT for wet asphalt")
plt.show()

# %%
plt.figure()
plt.plot(np.abs(np.fft.fft(testdata)))
plt.title("FFT for 30s of dry asphalt")
plt.show()

# %%
filtered = hpf(data2, samplerate, 65, 2)

sd.play(filtered, samplerate)

# %%
sd.play(data2, samplerate)

# %%
plt.figure()
plt.plot(data2)
plt.plot(filtered)

plt.title("Wet asphalt unfiltered and filtered")
plt.show()

# %%
plt.figure()
plt.plot(np.abs(np.fft.fft(filtered)))
plt.title("Wet asphalt fft 65hz")
plt.show()

# %%
filtereddry = hpf(data, samplerate, 65, 2)

plt.figure()
plt.plot(np.abs(np.fft.fft(filtereddry)))
plt.title("Dry asphalt fft 65hz")
plt.show()

# %%
sd.play(filtereddry, samplerate)

# %%
sd.play(filtered, samplerate)

# %%
plt.figure()
plt.plot(data)
plt.plot(filtereddry)
plt.title("Dry asphalt filtered and unfiltered")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
testdata = data[33*samplerate:80*samplerate]

# %%
filteredtest = hpf(testdata, samplerate, 65, 2)
plt.figure()
plt.plot(testdata)
plt.plot(filteredtest)
plt.title("Dry asphalt filtered and unfiltered")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
filtered = hpf(data2, samplerate, 65, 2)
plt.figure()
plt.plot(data2)
plt.plot(filtered)
plt.title("Wet asphalt unfiltered and filtered")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # We need
# ## -Recording of car just running
# ## -Gravel(or some other) recording
# ##

# %%
fs = samplerate
def slicing(sig, segment_length):   # this here will slice depending on the timeframe you give it
    sig_sliced = []                 # for example 10*fs is 10 seconds, so it will slice the signal
                                    # into 10s long segments
    for i in np.arange(int(len(sig)/segment_length)):
        sig_sliced.append( sig[i*segment_length:(i+1)*segment_length] )
        
    return (sig_sliced)

slice_data2 = slicing(filtered, 2*fs)

acf = np.correlate(slice_data2[1], slice_data2[1], mode='full')
acf = acf[acf.size//2:]
# Out:
# [array([ 29.45059183, -97.48084727, -16.4068128 , ..., 397.53186527,
#        320.19763557, 223.87153057]), array([   7.55358447, -216.75616982, -252.05769946, ...,  753.42949521,
#         630.9271278 ,  471.41877434]), array([  370.90466239,   289.38501589,    64.86005604, ...,
#        -1506.74743346, -1649.85122984,  -849.93912333]), array([ -31.01106497,  210.9330002 ,  624.89312888, ..., 3199.98169162,
#        2340.47541727, 1006.94333698]), array([-267.61468201, -951.19878005, -979.80909749, ...,  592.33248454,
#         391.09115761,  487.86268242]), array([ 492.64696588,  446.44391146,  639.25341906, ..., -237.64151037,
#        -261.69875872, -309.74303443]), array([-235.77421026,  140.20784283,  348.2032548 , ...,  895.20014911,
#         447.38534262,  266.57746723]), array([  43.77663018, -291.0170632 , -650.80350757, ..., 1607.78378792,
#        -203.26669808,  -19.32476852]), array([1554.60956355, 1887.53628103,  295.45535906, ...,  439.21032292,
# ...

# %%
plt.figure()
plt.plot(acf)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def derivate(arr, fs):
        b = np.array([1,2,0,-2,-1])*(1/8)*fs
        arr_f = signal.filtfilt(b,1,arr)
        return arr_f/max(arr_f)
    
def square(arr):
        return arr**2
    
def integrate(arr, fs):
        return np.convolve(arr, signal.triang(int(fs*0.15)), mode = 'same')

# %%
acfd = derivate(acf, fs)
acfd = square(acfd)
plt.figure()
plt.plot(acfd)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
