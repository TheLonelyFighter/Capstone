# %%
# !pip install tsfel
from tsfel.feature_extraction import features as tsfelf
import numpy as np
from scipy import signal
import pandas as pd
import glob
from scipy.io import wavfile
from scipy.signal import decimate
# Out:
# Requirement already satisfied: tsfel in c:\users\atter\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: setuptools>=47.1.1 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (58.0.4)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (1.3.4)
# Requirement already satisfied: oauth2client>=4.1.3 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (4.1.3)
# Requirement already satisfied: ipython>=7.4.0 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (7.29.0)
# Requirement already satisfied: Sphinx>=1.8.5 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (4.2.0)
# Requirement already satisfied: gspread>=3.1.0 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (5.1.1)
# Requirement already satisfied: scipy>=1.5.1 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (1.7.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\atter\anaconda3\lib\site-packages (from tsfel) (1.20.3)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\atter\anaconda3\lib\site-packages (from gspread>=3.1.0->tsfel) (0.4.6)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\atter\anaconda3\lib\site-packages (from gspread>=3.1.0->tsfel) (2.3.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\atter\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.1.0->tsfel) (4.2.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\atter\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.1.0->tsfel) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\atter\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.1.0->tsfel) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\atter\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread>=3.1.0->tsfel) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\atter\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (1.3.0)
# Requirement already satisfied: pickleshare in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (0.18.0)
# Requirement already satisfied: colorama in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (0.4.4)
# Requirement already satisfied: pygments in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (2.10.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (3.0.20)
# Requirement already satisfied: backcall in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (0.2.0)
# Requirement already satisfied: decorator in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (5.1.0)
# Requirement already satisfied: matplotlib-inline in c:\users\atter\anaconda3\lib\site-packages (from ipython>=7.4.0->tsfel) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\atter\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.4.0->tsfel) (0.8.2)
# Requirement already satisfied: httplib2>=0.9.1 in c:\users\atter\anaconda3\lib\site-packages (from oauth2client>=4.1.3->tsfel) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\users\atter\anaconda3\lib\site-packages (from oauth2client>=4.1.3->tsfel) (0.4.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\atter\anaconda3\lib\site-packages (from httplib2>=0.9.1->oauth2client>=4.1.3->tsfel) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\atter\anaconda3\lib\site-packages (from pandas>=0.25.3->tsfel) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\atter\anaconda3\lib\site-packages (from pandas>=0.25.3->tsfel) (2.8.2)
# Requirement already satisfied: wcwidth in c:\users\atter\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.4.0->tsfel) (0.2.5)
# Requirement already satisfied: requests>=2.0.0 in c:\users\atter\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (2.26.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\atter\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atter\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\atter\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\atter\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\atter\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread>=3.1.0->tsfel) (3.2)
# Requirement already satisfied: sphinxcontrib-applehelp in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (1.1.5)
# Requirement already satisfied: sphinxcontrib-qthelp in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (1.0.3)
# Requirement already satisfied: Jinja2>=2.3 in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (2.11.3)
# Requirement already satisfied: docutils<0.18,>=0.14 in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (0.17.1)
# Requirement already satisfied: snowballstemmer>=1.1 in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (2.1.0)
# Requirement already satisfied: babel>=1.3 in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (2.9.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (0.7.12)
# Requirement already satisfied: imagesize in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (1.2.0)
# Requirement already satisfied: packaging in c:\users\atter\anaconda3\lib\site-packages (from Sphinx>=1.8.5->tsfel) (21.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\atter\anaconda3\lib\site-packages (from Jinja2>=2.3->Sphinx>=1.8.5->tsfel) (1.1.1)

# %%
source_samp_rate=44100
decimation_factor = 4

# %% [markdown]
# #Preprocessing.
# Filtration and feature extraction

# %%
def hpf(arr,fs,lf,order):
    wbut = lf
    bbut, abut = signal.butter(order,wbut, btype='highpass', fs=fs)
    return signal.filtfilt(bbut, abut, arr)

def get_features(sig,label,fs = 44100):
    
    features = ["RMS", "RMS_filt", "Spectral_centroid", "Spectral_centroid_filt",\
                "Zero-Cross", "Zero-Cross_filt", "Spectral_slope", \
                    "Spectral_slope_filt", "Spectral_spread", \
                        "Spectral_spread_filt", "STD", "STD_filt"]

        
    s_f = hpf(sig, fs, 65, 2)
    RMS = tsfelf.rms(sig)
    RMS_filt= tsfelf.rms(s_f)
    
    Zero_Cross = tsfelf.zero_cross(sig)
    Zero_Cross_filt = tsfelf.zero_cross(s_f)
            
    Spectral_centroid = tsfelf.spectral_centroid(sig, fs)
    Spectral_centroid_filt = tsfelf.spectral_centroid(s_f, fs)
            
    Spectral_slope = tsfelf.spectral_slope(sig, fs)
    Spectral_slope_filt = tsfelf.spectral_slope(s_f, fs) 
            
    Spectral_spread = tsfelf.spectral_spread(sig, fs)
    Spectral_spread_filt = tsfelf.spectral_spread(s_f, fs) 
            
    STD = np.std(sig)
            
    STD_filt = np.std(s_f)

    return [label,RMS, RMS_filt, Zero_Cross, Zero_Cross_filt, Spectral_centroid, 
     Spectral_centroid_filt,Spectral_slope, Spectral_slope_filt, Spectral_spread, Spectral_spread_filt,  
      STD, STD_filt]

# %%
wg_path = "C:\\Users\\AtteR\\Desktop\\Wet gravel"
#wet_gravel_df = pd.DataFrame()

# %%
#
wg_files=glob.glob(wg_path+"/*.wav")
print(wg_files)

# %%
samplerate, data = wavfile.read(wg_files[0])
print(samplerate,data)

# %%
wg_features = []
for file_path in wg_files:
    samplerate, sdata=wavfile.read(file_path)
    decimated_data=decimate(sdata,decimation_factor)
    sample1=decimated_data[0:int(samplerate/decimation_factor*3-1)]
    sample2=decimated_data[int(samplerate/decimation_factor*3):int(samplerate/decimation_factor*6-1)]
    sample3=decimated_data[int(samplerate/decimation_factor*6):int(samplerate/decimation_factor*9-1)]
    features1=get_features(sample1,"Wet Gravel",samplerate/decimation_factor)
    features2=get_features(sample2,"Wet Gravel",samplerate/decimation_factor)
    features3=get_features(sample3,"Wet Gravel",samplerate/decimation_factor)
    wg_features.append(features1)
    wg_features.append(features2)
    wg_features.append(features3)

# %%
print(wg_features)
# Out:
# [['Wet Gravel', 121.36131809749838, 85.66330485275074, 1214, 1823, 706.9415625251071, 809.972502854982, -4.8933685023070076e-08, -4.647319707918017e-08, 892.8185297524504, 921.568378125202, 121.36056846669014, 85.66330138684029], ['Wet Gravel', 121.90214827468019, 85.40397070703878, 1848, 2742, 932.7300968143064, 1058.8196428804586, -4.3541615760104636e-08, -4.053046389685839e-08, 1101.399680725606, 1121.3505005573843, 121.90049301208536, 85.40396706413705], ['Wet Gravel', 143.28180471309255, 105.14578176416187, 3565, 5045, 1296.9443048741527, 1440.8023292284233, -3.484379484285918e-08, -3.1408312904887706e-08, 1250.8410036799442, 1237.9137111956707, 143.28178096470862, 105.14576505054569], ['Wet Gravel', 178.57684499761723, 131.94747599701756, 3382, 4469, 1170.1359729761057, 1333.2253123851224, -3.7872112072819084e-08, -3.397736596928871e